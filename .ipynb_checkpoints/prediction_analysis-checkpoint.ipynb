# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats
import statsmodels.api as sm
import seaborn as sns
from sklearn.linear_model import LinearRegression
from statsmodels.formula.api import ols
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# %%
data = pd.read_csv('out/prediction_data.csv')
medals = [1.0, 2.0, 3.0]
medal_athletes = data[data['medal'].isin(medals)]

# %%
medal_athletes
# Out:
#     Unnamed: 0              name  gender  height  weight  noc  game_year  \
# 6            6   Ashley Lawrence       1     163      59  CAN       2024
# 10          10   Caileigh Filmer       1     169      76  CAN       2024
# 12          12  Charity Williams       1     162      68  CAN       2024
# 32          32  Kyra Constantine       1     175      63  CAN       2024
# 42          42   Nichelle Prince       1     163      65  CAN       2024
#
#      age  is_host  AG.LND.TOTL.K2  ...  NY.GDP.MKTP.KD  NY.GDP.MKTP.KD.ZG  \
# 6   29.0        0    8.953429e+06  ...    1.743957e+12           1.115198
# 10  27.0        0    8.953429e+06  ...    1.743957e+12           1.115198
# 12  27.0        0    8.953429e+06  ...    1.743957e+12           1.115198
# 32  25.0        0    8.953429e+06  ...    1.743957e+12           1.115198
# 42  29.0        0    8.953429e+06  ...    1.743957e+12           1.115198
#
#     NY.GDP.PCAP.KD  NY.GDP.PCAP.KD.ZG  SH.XPD.CHEX.GD.ZS  SL.UEM.TOTL.ZS  \
# 6     47979.406403           0.118987          12.304889        5.709578
# 10    47979.406403           0.118987          12.304889        5.709578
# 12    47979.406403           0.118987          12.304889        5.709578
# 32    47979.406403           0.118987          12.304889        5.709578
# 42    47979.406403           0.118987          12.304889        5.709578
#
#     SN.ITK.MSFI.ZS  SP.POP.GROW   SP.POP.TOTL  medal
# 6             9.42     0.999836  3.880394e+07    3.0
# 10            9.42     0.999836  3.880394e+07    3.0
# 12            9.42     0.999836  3.880394e+07    3.0
# 32            9.42     0.999836  3.880394e+07    3.0
# 42            9.42     0.999836  3.880394e+07    3.0
#
# [5 rows x 25 columns]

# %%
data = pd.read_csv('out/historical_athletes.csv')

medal_mapping = {
    'Gold': 1,
    'Silver': 2,
    'Bronze': 3,
}
gender_mapping = {
    "Male": 0,
    "Female": 1
}

data['medal'] = data['medal'].map(medal_mapping)
data['gender'] = data['gender'].map(gender_mapping)

data[data['medal'].isin(medals)]

data.describe()
# Out:
#              gender        height        weight         medal     game_year  \
# count  80836.000000  80836.000000  80836.000000  80836.000000  80836.000000
# mean       0.337399    176.558204     70.630932      3.668081   1994.425825
# std        0.472825     10.099430     12.291489      0.809140     17.529838
# min        0.000000    127.000000     41.000000      1.000000   1960.000000
# 25%        0.000000    170.000000     61.000000      4.000000   1980.000000
# 50%        0.000000    177.000000     70.000000      4.000000   1996.000000
# 75%        1.000000    183.000000     80.000000      4.000000   2008.000000
# max        1.000000    215.000000     99.000000      4.000000   2020.000000
#
#                 age  AG.LND.TOTL.K2  EG.CFT.ACCS.ZS  EG.ELC.ACCS.ZS  \
# count  80836.000000    8.083600e+04    80836.000000    80836.000000
# mean      26.126973    2.433124e+06       91.909009       94.167410
# std        5.645244    4.106852e+06       24.320019       20.689833
# min       12.000000    7.200000e+02     -175.291156     -129.311953
# 25%       22.000000    1.289000e+05      100.000000       99.800000
# 50%       25.000000    3.645000e+05      100.000000      100.000000
# 75%       29.000000    1.943950e+06      100.000000      100.000000
# max       71.000000    1.638134e+07      122.926779      100.000000
#
#         EN.POP.DNST  ...  NY.GDP.DEFL.KD.ZG  NY.GDP.MKTP.KD  \
# count  80836.000000  ...       80836.000000    8.083600e+04
# mean     109.910842  ...          19.043923    1.783601e+12
# std      112.938575  ...         106.167270    3.574993e+12
# min        0.713448  ...         -63.637347   -2.722362e+11
# 25%       23.052057  ...           1.792398    1.137483e+11
# 50%       83.830939  ...           4.326127    4.653598e+11
# 75%      137.340525  ...           8.907868    1.596445e+12
# max     1286.171553  ...        4800.531644    1.969097e+13
#
#        NY.GDP.MKTP.KD.ZG  NY.GDP.PCAP.KD  NY.GDP.PCAP.KD.ZG  \
# count       80836.000000    80836.000000       80836.000000
# mean            2.855117    22030.497172           2.079805
# std             3.939261    17314.176728           3.730070
# min           -32.118570    -7579.291935         -31.177519
# 25%             1.038551     7178.347485           0.514437
# 50%             3.200509    19487.951212           2.341823
# 75%             4.937873    33818.823551           4.144042
# max            82.809329   110094.792339          51.097192
#
#        SH.XPD.CHEX.GD.ZS  SL.UEM.TOTL.ZS  SN.ITK.MSFI.ZS   SP.POP.GROW  \
# count       80836.000000    80836.000000    80836.000000  80836.000000
# mean            7.204218        8.904069        7.162703      0.778675
# std             3.309730        5.299975       25.437079      0.937506
# min            -3.857582       -5.951992     -262.221429     -5.165263
# 25%             5.070141        5.436000        2.200000      0.240467
# 50%             7.193134        7.529000        7.678571      0.686783
# 75%             9.060000       11.138204       16.771429      1.131540
# max            40.066394       45.341734      127.350000     19.052040
#
#         SP.POP.TOTL
# count  8.083600e+04
# mean   6.459752e+07
# std    7.885933e+07
# min    9.793900e+04
# 25%    1.000002e+07
# 50%    3.557415e+07
# 75%    8.191483e+07
# max    3.315269e+08
#
# [8 rows x 21 columns]

# %%
# Gold medalists
g_data = data[data['medal'] == 1]
g_data.describe()
# Out:
#             gender       height       weight   medal    game_year  \
# count  4342.000000  4342.000000  4342.000000  4342.0  4342.000000
# mean      0.390143   178.426301    72.650161     1.0  1996.356518
# std       0.487838    10.511716    12.651383     0.0    17.344884
# min       0.000000   143.000000    41.000000     1.0  1960.000000
# 25%       0.000000   171.000000    63.000000     1.0  1984.000000
# 50%       0.000000   178.000000    73.000000     1.0  2000.000000
# 75%       1.000000   186.000000    82.000000     1.0  2012.000000
# max       1.000000   211.000000    99.000000     1.0  2020.000000
#
#                age  AG.LND.TOTL.K2  EG.CFT.ACCS.ZS  EG.ELC.ACCS.ZS  \
# count  4342.000000    4.342000e+03     4342.000000     4342.000000
# mean     26.061032    4.316605e+06       95.855528       97.177338
# std       5.305607    5.088317e+06       18.486736       14.535164
# min      14.000000    1.083000e+04      -38.343281      -77.474407
# 25%      22.000000    2.941100e+05      100.000000      100.000000
# 50%      26.000000    5.475570e+05      100.000000      100.000000
# 75%      29.000000    9.158960e+06      100.000000      100.000000
# max      57.000000    1.638134e+07      100.054150      100.000000
#
#        EN.POP.DNST  ...  NY.GDP.DEFL.KD.ZG  NY.GDP.MKTP.KD  NY.GDP.MKTP.KD.ZG  \
# count  4342.000000  ...        4342.000000    4.342000e+03        4342.000000
# mean    107.246068  ...          12.290796    4.152456e+12           2.812164
# std     116.320220  ...          59.337859    5.644573e+12           3.552570
# min       1.691137  ...          -2.517261   -2.722362e+11         -21.168656
# 25%      25.507625  ...           1.792398    3.046968e+11           0.959879
# 50%      59.546752  ...           3.265326    1.375281e+12           3.262901
# 75%     135.851152  ...           6.710771    5.007285e+12           4.700000
# max     518.013068  ...         969.012963    1.969097e+13          17.082429
#
#        NY.GDP.PCAP.KD  NY.GDP.PCAP.KD.ZG  SH.XPD.CHEX.GD.ZS  SL.UEM.TOTL.ZS  \
# count     4342.000000        4342.000000        4342.000000     4342.000000
# mean     27523.193082           2.128342           8.772332        7.971390
# std      18355.133944           3.385699           3.971496        4.364273
# min      -7579.291935         -19.717433          -2.203128       -5.951992
# 25%       9464.010742           0.691238           5.925634        5.451000
# 50%      28509.143055           2.552719           8.224642        6.785948
# 75%      40636.806616           3.881185          10.853456        9.942000
# max      84637.013231          13.049681          27.899692       30.091001
#
#        SN.ITK.MSFI.ZS  SP.POP.GROW   SP.POP.TOTL
# count     4342.000000  4342.000000  4.342000e+03
# mean         9.545368     0.684650  1.176578e+08
# std         26.258974     0.740464  1.068094e+08
# min       -262.221429    -2.096943  1.329522e+06
# 25%          4.764286     0.265287  2.185660e+07
# 50%          9.800000     0.724676  8.042582e+07
# 75%         18.707143     0.997795  2.098960e+08
# max        127.350000     5.752351  3.315269e+08
#
# [8 rows x 21 columns]

# %%
# Silver medalists
s_data = data[data['medal'] == 2]
s_data.describe()
# Out:
#             gender       height       weight   medal    game_year  \
# count  4473.000000  4473.000000  4473.000000  4473.0  4473.000000
# mean      0.391907   177.833445    72.219987     2.0  1996.287503
# std       0.488231    10.685943    12.632938     0.0    16.917895
# min       0.000000   143.000000    41.000000     2.0  1960.000000
# 25%       0.000000   170.000000    63.000000     2.0  1984.000000
# 50%       0.000000   178.000000    72.000000     2.0  2000.000000
# 75%       1.000000   185.000000    82.000000     2.0  2012.000000
# max       1.000000   212.000000    99.000000     2.0  2020.000000
#
#                age  AG.LND.TOTL.K2  EG.CFT.ACCS.ZS  EG.ELC.ACCS.ZS  \
# count  4473.000000    4.473000e+03     4473.000000     4473.000000
# mean     26.172144    3.403597e+06       95.429372       97.308061
# std       5.472967    4.818908e+06       18.408928       13.453374
# min      14.000000    1.083000e+04      -53.691749      -61.387473
# 25%      23.000000    2.935592e+05      100.000000       99.992937
# 50%      26.000000    4.073106e+05      100.000000      100.000000
# 75%      29.000000    8.965590e+06      100.000000      100.000000
# max      66.000000    1.638134e+07      103.255632      100.000000
#
#        EN.POP.DNST  ...  NY.GDP.DEFL.KD.ZG  NY.GDP.MKTP.KD  NY.GDP.MKTP.KD.ZG  \
# count  4473.000000  ...        4473.000000    4.473000e+03        4473.000000
# mean    116.805488  ...          17.484309    2.831348e+12           2.493468
# std     121.201056  ...          61.650319    4.574490e+12           3.688962
# min       0.795124  ...          -2.517261   -2.722362e+11         -32.118570
# 25%      23.926102  ...           1.549889    2.056580e+11           0.878704
# 50%      85.632245  ...           3.527500    9.295505e+11           2.764648
# 75%     178.669281  ...           7.943127    2.604143e+12           4.560985
# max     518.013068  ...         969.012963    1.969097e+13          17.742718
#
#        NY.GDP.PCAP.KD  NY.GDP.PCAP.KD.ZG  SH.XPD.CHEX.GD.ZS  SL.UEM.TOTL.ZS  \
# count     4473.000000        4473.000000        4473.000000     4473.000000
# mean     25030.076124           1.879982           8.011964        8.597765
# std      17504.557701           3.539497           3.353489        4.786754
# min      -7579.291935         -31.177519          -2.203128       -5.284957
# 25%       8554.822300           0.254474           5.520000        5.690930
# 50%      26514.324812           2.076625           7.832103        7.500000
# 75%      37884.391321           3.881185          10.164293       10.628000
# max      84637.013231          14.686185          18.756220       30.091001
#
#        SN.ITK.MSFI.ZS  SP.POP.GROW   SP.POP.TOTL
# count     4473.000000  4473.000000  4.473000e+03
# mean         8.037989     0.640012  9.102043e+07
# std         25.608625     0.698184  9.394175e+07
# min       -242.635714    -2.443855  3.174140e+05
# 25%          3.971429     0.247414  1.628178e+07
# 50%          8.135714     0.647183  5.323575e+07
# 75%         16.771429     0.987284  1.440673e+08
# max        103.478571     3.966988  3.315269e+08
#
# [8 rows x 21 columns]

# %%
# Bronze medalists|
b_data = data[data['medal'] == 3]
b_data.describe()
# Out:
#             gender       height       weight   medal    game_year  \
# count  4859.000000  4859.000000  4859.000000  4859.0  4859.000000
# mean      0.386293   177.476435    71.947108     3.0  1995.530356
# std       0.486949    10.636535    12.658590     0.0    17.316968
# min       0.000000   142.000000    41.000000     3.0  1960.000000
# 25%       0.000000   170.000000    62.000000     3.0  1984.000000
# 50%       0.000000   178.000000    72.000000     3.0  2000.000000
# 75%       1.000000   185.000000    81.000000     3.0  2010.000000
# max       1.000000   210.000000    99.000000     3.0  2020.000000
#
#                age  AG.LND.TOTL.K2  EG.CFT.ACCS.ZS  EG.ELC.ACCS.ZS  \
# count  4859.000000    4.859000e+03     4859.000000     4859.000000
# mean     26.157028    3.254133e+06       95.956122       97.505166
# std       5.393476    4.799346e+06       16.740427       12.684947
# min      14.000000    2.030000e+03      -42.891897      -70.849207
# 25%      23.000000    2.633100e+05      100.000000       99.992402
# 50%      26.000000    3.647000e+05      100.000000      100.000000
# 75%      29.000000    8.358140e+06      100.000000      100.000000
# max      58.000000    1.638134e+07      105.714526      100.000000
#
#        EN.POP.DNST  ...  NY.GDP.DEFL.KD.ZG  NY.GDP.MKTP.KD  NY.GDP.MKTP.KD.ZG  \
# count  4859.000000  ...        4859.000000    4.859000e+03        4859.000000
# mean    118.121066  ...          18.751630    2.601290e+12           2.557158
# std     116.028717  ...          64.386850    4.390759e+12           3.874123
# min       0.795124  ...         -17.460580   -2.722362e+11         -32.118570
# 25%      23.805650  ...           1.547301    1.610356e+11           0.928813
# 50%      93.049263  ...           3.545390    9.712537e+11           2.912503
# 75%     192.365843  ...           9.085205    2.604143e+12           4.560985
# max     612.867488  ...         942.306569    1.969097e+13          18.008555
#
#        NY.GDP.PCAP.KD  NY.GDP.PCAP.KD.ZG  SH.XPD.CHEX.GD.ZS  SL.UEM.TOTL.ZS  \
# count     4859.000000        4859.000000        4859.000000     4859.000000
# mean     23781.722661           1.997205           7.826753        8.813876
# std      17791.642298           3.731705           3.379756        4.990252
# min      -7579.291935         -31.177519          -2.203128       -5.951992
# 25%       7449.658122           0.449644           5.293636        5.690930
# 50%      24634.962088           2.151723           7.614358        7.763000
# 75%      35651.015637           3.871731           9.888435       10.726197
# max      84637.013231          16.212148          18.756220       32.200000
#
#        SN.ITK.MSFI.ZS  SP.POP.GROW   SP.POP.TOTL
# count     4859.000000  4859.000000  4.859000e+03
# mean         8.074315     0.600122  8.534424e+07
# std         21.447141     0.738018  8.879845e+07
# min       -262.221429    -3.629546  2.395110e+05
# 25%          3.592857     0.135432  1.628178e+07
# 50%          8.007143     0.620164  5.505258e+07
# 75%         16.092857     0.987284  1.276290e+08
# max        111.435714     7.676428  3.315269e+08
#
# [8 rows x 21 columns]

# %%
plt.figure(figsize=(10, 6))
plt.hist(data['weight'], bins=20, color='blue', alpha=0.7)
plt.title('Distribution of Medalist Athlete Weights')
plt.xlabel('Weight (kg)')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(data['height'], bins=20, color='blue', alpha=0.7)
plt.title('Distribution of Medalist Athlete Heights')
plt.xlabel('Height (cm)')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(data['age'], bins=20, color='blue', alpha=0.7)
plt.title('Distribution of Medalist Athlete Ages')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
relevant_columns = ['height', 'weight', 'age', 'medal', 'AG.LND.TOTL.K2', 'EG.CFT.ACCS.ZS', 'EG.ELC.ACCS.ZS',
                    'EN.POP.DNST', 'NY.ADJ.NNTY.KD', 'NY.GDP.DEFL.KD.ZG', 'NY.GDP.MKTP.KD', 'NY.GDP.MKTP.KD.ZG',
                    'NY.GDP.PCAP.KD', 'NY.GDP.PCAP.KD.ZG', 'SH.XPD.CHEX.GD.ZS', 'SL.UEM.TOTL.ZS', 'SN.ITK.MSFI.ZS',
                    'SP.POP.GROW', 'SP.POP.TOTL'

]
selected_data = data[relevant_columns]

corr_matrix = selected_data.corr()

# %%
threshold = 0.7

high_corr = corr_matrix[(corr_matrix.abs() >= threshold) & (corr_matrix != 1)]
high_corr = high_corr.dropna(axis=0, how='all').dropna(axis=1, how='all')

print(high_corr)

plt.figure(figsize=(10, 8))
sns.heatmap(high_corr, annot=True, cmap='coolwarm', linewidths=0.5, vmin=-1, vmax=1)
plt.title('High Correlation Matrix (|corr| >= 0.7)')
plt.show()
# Out:
#                      height    weight  EG.CFT.ACCS.ZS  EG.ELC.ACCS.ZS  \
# height                  NaN  0.803361             NaN             NaN
# weight             0.803361       NaN             NaN             NaN
# EG.CFT.ACCS.ZS          NaN       NaN             NaN        0.882338
# EG.ELC.ACCS.ZS          NaN       NaN        0.882338             NaN
# NY.ADJ.NNTY.KD          NaN       NaN             NaN             NaN
# NY.GDP.MKTP.KD          NaN       NaN             NaN             NaN
# NY.GDP.MKTP.KD.ZG       NaN       NaN             NaN             NaN
# NY.GDP.PCAP.KD.ZG       NaN       NaN             NaN             NaN
# SP.POP.TOTL             NaN       NaN             NaN             NaN
#
#                    NY.ADJ.NNTY.KD  NY.GDP.MKTP.KD  NY.GDP.MKTP.KD.ZG  \
# height                        NaN             NaN                NaN
# weight                        NaN             NaN                NaN
# EG.CFT.ACCS.ZS                NaN             NaN                NaN
# EG.ELC.ACCS.ZS                NaN             NaN                NaN
# NY.ADJ.NNTY.KD                NaN        0.997316                NaN
# NY.GDP.MKTP.KD           0.997316             NaN                NaN
# NY.GDP.MKTP.KD.ZG             NaN             NaN                NaN
# NY.GDP.PCAP.KD.ZG             NaN             NaN           0.966707
# SP.POP.TOTL              0.851203        0.862585                NaN
#
#                    NY.GDP.PCAP.KD.ZG  SP.POP.TOTL
# height                           NaN          NaN
# weight                           NaN          NaN
# EG.CFT.ACCS.ZS                   NaN          NaN
# EG.ELC.ACCS.ZS                   NaN          NaN
# NY.ADJ.NNTY.KD                   NaN     0.851203
# NY.GDP.MKTP.KD                   NaN     0.862585
# NY.GDP.MKTP.KD.ZG           0.966707          NaN
# NY.GDP.PCAP.KD.ZG                NaN          NaN
# SP.POP.TOTL                      NaN          NaN

# %%
X = data[['height', 'weight', 'age', 'AG.LND.TOTL.K2', 'EG.CFT.ACCS.ZS', 'EG.ELC.ACCS.ZS',
                    'EN.POP.DNST', 'NY.ADJ.NNTY.KD', 'NY.GDP.DEFL.KD.ZG', 'NY.GDP.MKTP.KD', 'NY.GDP.MKTP.KD.ZG',
                    'NY.GDP.PCAP.KD', 'NY.GDP.PCAP.KD.ZG', 'SH.XPD.CHEX.GD.ZS', 'SL.UEM.TOTL.ZS', 'SN.ITK.MSFI.ZS',
                    'SP.POP.GROW', 'SP.POP.TOTL']]
y = data['medal']

X = sm.add_constant(X)
model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  medal   R-squared:                       0.052
# Model:                            OLS   Adj. R-squared:                  0.052
# Method:                 Least Squares   F-statistic:                     245.0
# Date:                Wed, 31 Jul 2024   Prob (F-statistic):               0.00
# Time:                        13:25:54   Log-Likelihood:                -95433.
# No. Observations:               80836   AIC:                         1.909e+05
# Df Residuals:                   80817   BIC:                         1.911e+05
# Df Model:                          18
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 4.3100      0.068     63.448      0.000       4.177       4.443
# height               -0.0018      0.000     -3.860      0.000      -0.003      -0.001
# weight               -0.0025      0.000     -6.609      0.000      -0.003      -0.002
# age                   0.0021      0.001      4.124      0.000       0.001       0.003
# AG.LND.TOTL.K2    -8.645e-09   1.14e-09     -7.575      0.000   -1.09e-08   -6.41e-09
# EG.CFT.ACCS.ZS       -0.0004      0.000     -1.435      0.151      -0.001       0.000
# EG.ELC.ACCS.ZS        0.0005      0.000      1.669      0.095    -8.7e-05       0.001
# EN.POP.DNST          -0.0003   3.12e-05     -9.883      0.000      -0.000      -0.000
# NY.ADJ.NNTY.KD     8.093e-14   1.32e-14      6.125      0.000     5.5e-14    1.07e-13
# NY.GDP.DEFL.KD.ZG  2.931e-05   2.72e-05      1.079      0.281   -2.39e-05    8.25e-05
# NY.GDP.MKTP.KD    -7.608e-14   1.17e-14     -6.503      0.000    -9.9e-14   -5.31e-14
# NY.GDP.MKTP.KD.ZG     0.1192      0.013      9.516      0.000       0.095       0.144
# NY.GDP.PCAP.KD     2.039e-07   2.67e-07      0.765      0.444   -3.19e-07    7.26e-07
# NY.GDP.PCAP.KD.ZG    -0.1222      0.013     -9.540      0.000      -0.147      -0.097
# SH.XPD.CHEX.GD.ZS    -0.0130      0.001     -9.596      0.000      -0.016      -0.010
# SL.UEM.TOTL.ZS        0.0013      0.001      2.199      0.028       0.000       0.003
# SN.ITK.MSFI.ZS        0.0003      0.000      2.290      0.022    3.79e-05       0.000
# SP.POP.GROW          -0.0902      0.014     -6.628      0.000      -0.117      -0.064
# SP.POP.TOTL       -1.237e-09   1.01e-10    -12.214      0.000   -1.44e-09   -1.04e-09
# ==============================================================================
# Omnibus:                    34567.230   Durbin-Watson:                   1.716
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           125370.799
# Skew:                          -2.234   Prob(JB):                         0.00
# Kurtosis:                       7.153   Cond. No.                     1.28e+14
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.28e+14. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
data['age_group'] = pd.cut(data['age'], bins=[0, 20, 30, 40, 50, 60, 70], 
                           labels=['0-20', '21-30', '31-40', '41-50', '51-60', '61-70']).astype('category')

data['medal'] = pd.to_numeric(data['medal'], errors='coerce')
data['age_group'] = data['age_group'].astype('category')
data = data.dropna(subset=['medal', 'age_group'])

# ANOVA
f_value, p_value = stats.f_oneway(
    data[data['age_group'] == '0-20']['medal'],
    data[data['age_group'] == '21-30']['medal'],
    data[data['age_group'] == '31-40']['medal'],
    data[data['age_group'] == '41-50']['medal'],
    data[data['age_group'] == '51-60']['medal'],
    data[data['age_group'] == '61-70']['medal'],
)

print('ANOVA F-value:', f_value)
print('ANOVA p-value:', p_value)
# Out:
# ANOVA F-value: 8.582578696166799
# ANOVA p-value: 3.8674408654472974e-08

# %%
model = ols('medal ~ C(age_group)', data=data).fit()
aov_table = sm.stats.anova_lm(model, typ=2)
print(aov_table)
# Out:
#                     sum_sq       df         F        PR(>F)
# C(age_group)     28.082512      5.0  8.582579  3.867441e-08
# Residual      52895.090049  80829.0       NaN           NaN

# %%
tukey = pairwise_tukeyhsd(endog=data['medal'], groups=data['age_group'], alpha=0.05)
print(tukey)
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#   0-20  21-30  -0.0428    0.0 -0.0674 -0.0182   True
#   0-20  31-40  -0.0141 0.7724 -0.0444  0.0163  False
#   0-20  41-50   0.0314 0.7309 -0.0328  0.0955  False
#   0-20  51-60    0.026  0.997 -0.1303  0.1824  False
#   0-20  61-70   0.0655 0.9995 -0.4941  0.6251  False
#  21-30  31-40   0.0287 0.0037  0.0063  0.0512   True
#  21-30  41-50   0.0741 0.0067  0.0134  0.1349   True
#  21-30  51-60   0.0688  0.804 -0.0862  0.2239  False
#  21-30  61-70   0.1083 0.9939 -0.4509  0.6675  False
#  31-40  41-50   0.0454 0.3166 -0.0179  0.1087  False
#  31-40  51-60   0.0401 0.9779 -0.1159  0.1962  False
#  31-40  61-70   0.0796 0.9986 -0.4799  0.6391  False
#  41-50  51-60  -0.0053    1.0 -0.1713  0.1606  False
#  41-50  61-70   0.0342    1.0 -0.5282  0.5965  False
#  51-60  61-70   0.0395    1.0 -0.5407  0.6196  False
# ----------------------------------------------------

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
athletes = pd.read_csv('data/athletes.csv')
athletes
# Out:
#             id                     name  gender            born died  height  \
# 0       131892           Meryem Erdoğan  Female   24 April 1990  NaN  172 cm
# 1       131892           Meryem Erdoğan  Female   24 April 1990  NaN  172 cm
# 2       131892           Meryem Erdoğan  Female   24 April 1990  NaN  172 cm
# 3         4300            Maurice Maina    Male  1 January 1963  NaN  158 cm
# 4         4300            Maurice Maina    Male  1 January 1963  NaN  158 cm
# ...        ...                      ...     ...             ...  ...     ...
# 476343   20989  Caitlin Bilodeaux-Banos  Female   17 March 1965  NaN  170 cm
# 476344   20989  Caitlin Bilodeaux-Banos  Female   17 March 1965  NaN  170 cm
# 476345   20989  Caitlin Bilodeaux-Banos  Female   17 March 1965  NaN  170 cm
# 476346   20989  Caitlin Bilodeaux-Banos  Female   17 March 1965  NaN  170 cm
# 476347   20989  Caitlin Bilodeaux-Banos  Female   17 March 1965  NaN  170 cm
#
#        weight           team                  game  noc      sport  \
# 0       55 kg        Türkiye  2016 Summer Olympics  TUR  Athletics
# 1       55 kg        Türkiye  2020 Summer Olympics  TUR  Athletics
# 2       55 kg        Türkiye  2020 Summer Olympics  TUR  Athletics
# 3       47 kg          Kenya  1988 Summer Olympics  KEN     Boxing
# 4       47 kg          Kenya  1988 Summer Olympics  KEN     Boxing
# ...       ...            ...                   ...  ...        ...
# 476343  64 kg  United States  1988 Summer Olympics  USA    Fencing
# 476344  64 kg  United States  1988 Summer Olympics  USA    Fencing
# 476345  64 kg  United States  1992 Summer Olympics  USA    Fencing
# 476346  64 kg  United States  1992 Summer Olympics  USA    Fencing
# 476347  64 kg  United States  1992 Summer Olympics  USA    Fencing
#
#                                             event medal
# 0             Athletics, Marathon, Women(Olympic)   NaN
# 1             Athletics, Marathon, Women(Olympic)   NaN
# 2             Athletics, Marathon, Women(Olympic)   NaN
# 3           Boxing, Light-Flyweight, Men(Olympic)   NaN
# 4           Boxing, Light-Flyweight, Men(Olympic)   NaN
# ...                                           ...   ...
# 476343  Fencing, Foil, Individual, Women(Olympic)   NaN
# 476344        Fencing, Foil, Team, Women(Olympic)   NaN
# 476345  Fencing, Foil, Individual, Women(Olympic)   NaN
# 476346        Fencing, Foil, Team, Women(Olympic)   NaN
# 476347        Fencing, Foil, Team, Women(Olympic)   NaN
#
# [476348 rows x 13 columns]

# %%
athletes['height'] = athletes['height'].str.replace(' cm', '')
athletes['weight'] = athletes['weight'].str.replace(' kg', '')
athletes['weight'] = athletes['weight'].str.extract(r'(\d{2})')

athletes['weight'].dropna()

athletes['height'] = athletes['height'].astype(int)
athletes['weight'] = athletes['weight'].astype(int)
athletes['age'] = athletes['age'].astype(int)
athletes = athletes[athletes['weight'] >= 41]
    
plt.figure(figsize=(10, 6))
plt.hist(athletes['weight'], bins=20, color='blue', alpha=0.7)
plt.title('Distribution of Medalist Athlete Weights')
plt.xlabel('Weight (kg)')
plt.ylabel('Frequency')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_41856\1851158819.py in <module>
#       2 athletes['weight'] = athletes['weight'].str.replace(' kg', '')
#       3 athletes['weight'] = athletes['weight'].str.extract(r'(\d{2})')
# ----> 4 athletes['height'] = athletes['height'].astype(int)
#       5 athletes['weight'] = athletes['weight'].astype(int)
#       6 athletes['age'] = athletes['age'].astype(int)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5910         else:
#    5911             # else, only a single dtype is given
# -> 5912             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913             return self._constructor(new_data).__finalize__(self, method="astype")
#    5914
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     417
#     418     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 419         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     420
#     421     def convert(
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     302                     applied = b.apply(f, **kwargs)
#     303                 else:
# --> 304                     applied = getattr(b, f)(**kwargs)
#     305             except (TypeError, NotImplementedError):
#     306                 if not ignore_failures:
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     578         values = self.values
#     579
# --> 580         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     581
#     582         new_values = maybe_coerce_values(new_values)
#
# ~\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_array_safe(values, dtype, copy, errors)
#    1290
#    1291     try:
# -> 1292         new_values = astype_array(values, dtype, copy=copy)
#    1293     except (ValueError, TypeError):
#    1294         # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_array(values, dtype, copy)
#    1235
#    1236     else:
# -> 1237         values = astype_nansafe(values, dtype, copy=copy)
#    1238
#    1239     # in pandas we don't store numpy str dtypes, so convert to object
#
# ~\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1152         # work around NumPy brokenness, #1987
#    1153         if np.issubdtype(dtype.type, np.integer):
# -> 1154             return lib.astype_intsafe(arr, dtype)
#    1155
#    1156         # if we have a datetime/timedelta array of objects
#
# ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.astype_intsafe()
#
# ValueError: cannot convert float NaN to integer
